# %% [markdown]
# Set
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# A set is a collection which is unordered, unchangeable*, and unindexed.
#
# * Note: Set items are unchangeable, but you can remove items and add new items.
#
# Sets are written with curly brackets.{ }

# %%
thisSet={"a","b","c"}
#Note: Sets are unordered, so you cannot be sure in which order the items will appear.
print(thisSet)

# %% [markdown]
# Once a set is created, you cannot change its items, but you can add new items.

# %%
thisset={"a","b","c","a"}
print(thisset)# while a is repeated, it will only print one a because sets do not allow duplicates
thisset.add("d")
print(thisset)
# Out:
# {'c', 'b', 'a'}
# {'c', 'b', 'a', 'd'}

# %% [markdown]
# Add Sets
# To add items from another set into the current set, use the update() method.

# %%
thisset={"a","b","c","a"}
tropical={"mango","pineapple","papaya"}
thisset.update(tropical)
print(thisset)
# Out:
# {'c', 'a', 'mango', 'b', 'papaya', 'pineapple'}

# %% [markdown]
# Add Any Iterable
# The object in the update() method does not have to be a set, it can be any iterable object (tuples, lists, dictionaries etc.).

# %%
thisset={"a","b","c","a"}
mylist=["d","e","f"]
thisset.update(mylist)
# mylist.update(thisset) # this will give an error because lists do not have the update() method
print(thisset)
print(mylist)
# Out:
# {'d', 'c', 'a', 'e', 'b', 'f'}
# ['d', 'e', 'f']

# %% [markdown]
# Remove a item

# %%
thisset={"a","b","c","a"}
thisset.remove("b")#Note: If the item to remove does not exist, remove() will raise an error.
print(thisset)

thisset.discard("b")#Note: If the item to remove does not exist, discard() will NOT raise an error.
print(thisset)

thisset.pop()#Note: Sets are unordered, so when using the pop() method, you do not know which item that gets removed.
print(thisset)

thisset.clear()#The clear() method empties the set.
print(thisset)

del thisset
#print(thisset) #this will give an error because the set no longer exists
# Out:
# {'c', 'a'}
# {'c', 'a'}
# {'a'}
# set()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 15
#      12 print(thisset)
#      14 del thisset
# ---> 15 print(thisset)
#
# NameError: name 'thisset' is not defined

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %% [markdown]
# Symmetric Differences
# The symmetric_difference() method will keep only the elements that are NOT present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'cherry', 'google', 'banana', 'microsoft'}

# %% [markdown]
# The symmetric_difference_update() method will also keep all but the duplicates, but it will change the original set instead of returning a new set.
#
# Use the symmetric_difference_update() method to keep the items that are not present in both sets:

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
print(set2)
# Out:
# {'cherry', 'google', 'banana', 'microsoft'}
# {'apple', 'google', 'microsoft'}

# %% [markdown]
# Creating a frozenset
# Use the frozenset() constructor to create a frozenset from any iterable.

# %%
#Create a frozenset and check its type:

x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'apple', 'cherry', 'banana'})
# <class 'frozenset'>

# %% [markdown]
# Frozenset Methods
# Being immutable means you cannot add or remove elements. However, frozensets support all non-mutating operations of sets.
#
# <table border="1" cellpadding="8">
#   <tr>
#     <th>Method</th>
#     <th>Description</th>
#     <th>Example</th>
#   </tr>
#
#   <tr>
#     <td>copy()</td>
#     <td>Returns a shallow copy of the frozenset</td>
#     <td>fs.copy()</td>
#   </tr>
#
#   <tr>
#     <td>union()</td>
#     <td>Returns a new frozenset with all unique elements from both sets</td>
#     <td>fs1.union(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>intersection()</td>
#     <td>Returns common elements of sets</td>
#     <td>fs1.intersection(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>difference()</td>
#     <td>Returns elements present in first set but not in second</td>
#     <td>fs1.difference(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>symmetric_difference()</td>
#     <td>Returns elements that are in either set but not both</td>
#     <td>fs1.symmetric_difference(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>isdisjoint()</td>
#     <td>Returns True if two sets have no common elements</td>
#     <td>fs1.isdisjoint(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>issubset()</td>
#     <td>Checks if all elements of set are in another set</td>
#     <td>fs1.issubset(fs2)</td>
#   </tr>
#
#   <tr>
#     <td>issuperset()</td>
#     <td>Checks if set contains all elements of another set</td>
#     <td>fs1.issuperset(fs2)</td>
#   </tr>
# </table>
#
# 🧠 Important Note
#
# 👉 frozenset is immutable, so:
#
# ❌ No add()
# ❌ No remove()
# ❌ No update()
#
# But it still supports set operations that return new frozensets.

# %% [markdown]
# <table border="1" cellpadding="8">
#   <tr>
#     <th>Method</th>
#     <th>Description</th>
#     <th>Example</th>
#   </tr>
#
#   <tr>
#     <td>add()</td>
#     <td>Adds a single element to the set</td>
#     <td>s.add(5)</td>
#   </tr>
#
#   <tr>
#     <td>update()</td>
#     <td>Adds multiple elements to the set</td>
#     <td>s.update([1,2,3])</td>
#   </tr>
#
#   <tr>
#     <td>remove()</td>
#     <td>Removes an element (error if not found)</td>
#     <td>s.remove(3)</td>
#   </tr>
#
#   <tr>
#     <td>discard()</td>
#     <td>Removes an element (no error if not found)</td>
#     <td>s.discard(3)</td>
#   </tr>
#
#   <tr>
#     <td>pop()</td>
#     <td>Removes and returns a random element</td>
#     <td>s.pop()</td>
#   </tr>
#
#   <tr>
#     <td>clear()</td>
#     <td>Removes all elements from the set</td>
#     <td>s.clear()</td>
#   </tr>
#
#   <tr>
#     <td>copy()</td>
#     <td>Returns a copy of the set</td>
#     <td>s.copy()</td>
#   </tr>
#
#   <tr>
#     <td>union()</td>
#     <td>Returns all unique elements from sets</td>
#     <td>s1.union(s2)</td>
#   </tr>
#
#   <tr>
#     <td>intersection()</td>
#     <td>Returns common elements</td>
#     <td>s1.intersection(s2)</td>
#   </tr>
#
#   <tr>
#     <td>difference()</td>
#     <td>Returns elements in first set but not second</td>
#     <td>s1.difference(s2)</td>
#   </tr>
#
#   <tr>
#     <td>symmetric_difference()</td>
#     <td>Returns elements not common in both sets</td>
#     <td>s1.symmetric_difference(s2)</td>
#   </tr>
#
#   <tr>
#     <td>intersection_update()</td>
#     <td>Updates set with common elements</td>
#     <td>s1.intersection_update(s2)</td>
#   </tr>
#
#   <tr>
#     <td>difference_update()</td>
#     <td>Updates set by removing common elements</td>
#     <td>s1.difference_update(s2)</td>
#   </tr>
#
#   <tr>
#     <td>symmetric_difference_update()</td>
#     <td>Updates set with non-common elements</td>
#     <td>s1.symmetric_difference_update(s2)</td>
#   </tr>
#
#   <tr>
#     <td>isdisjoint()</td>
#     <td>Checks if two sets have no common elements</td>
#     <td>s1.isdisjoint(s2)</td>
#   </tr>
#
#   <tr>
#     <td>issubset()</td>
#     <td>Checks if set is subset of another</td>
#     <td>s1.issubset(s2)</td>
#   </tr>
#
#   <tr>
#     <td>issuperset()</td>
#     <td>Checks if set contains another set</td>
#     <td>s1.issuperset(s2)</td>
#   </tr>
# </table>
#
#
# 🧠 Important Understanding
# Methods like union(), intersection() → return new set
# Methods like update(), intersection_update() → modify original set
# Set does NOT allow duplicates
# Set is mutable container of immutable items
