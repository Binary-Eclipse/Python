# %% [markdown]
# from IPython.display import HTML
#
# HTML("""
# <table border="1" cellpadding="10" cellspacing="0">
#     <thead>
#         <tr>
#             <th>Operator Type</th>
#             <th>Description</th>
#             <th>Link</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Arithmetic Operators</td>
#             <td>Perform mathematical operations</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_arithmetic.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Assignment Operators</td>
#             <td>Assign values to variables</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_assign.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Comparison Operators</td>
#             <td>Compare two values</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_comparison.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Logical Operators</td>
#             <td>Combine conditional statements</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_logical.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Identity Operators</td>
#             <td>Compare object identity</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_identity.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Membership Operators</td>
#             <td>Test value in a sequence</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_membership.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Bitwise Operators</td>
#             <td>Perform operations on binary numbers</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_bitwise.asp" target="_blank">View</a></td>
#         </tr>
#         <tr>
#             <td>Operator Precedence</td>
#             <td>Order of operator execution</td>
#             <td><a href="https://www.w3schools.com/python/python_operators_precedence.asp" target="_blank">View</a></td>
#         </tr>
#     </tbody>
# </table>
# """)
