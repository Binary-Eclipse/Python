# %% [markdown]
# Python divides the operators in the following groups:
# <a href=" https://www.w3schools.com/python/python_operators_arithmetic.asp"><ul>Arithmetic operators<ul></a>
# <a href=" https://www.w3schools.com/python/python_operators_assign.asp"><ul>Assignment operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_comparison.asp"><ul>Comparison operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_logical.asp"><ul>Logical operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_identity.asp"><ul>Identity operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_membership.asp"><ul>Membership operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_bitwise.asp"><ul>Bitwise operators<ul></a>
# <a href="https://www.w3schools.com/python/python_operators_precedence.asp"><ul>Operators Precedence<ul></a>
