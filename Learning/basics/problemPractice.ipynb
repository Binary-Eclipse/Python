# %% [markdown]
# 1.Print "Hello World"

# %%
print("Hello World")

# %% [markdown]
# 2.Swap two variables (with/without temp variable)

# %%
#with temp variable
a=input()
b=input()
print(a,b)
temp=a
a=b
b=temp
print(a,b)

#without temp variable
a=input()
b=input()
print(a,b)
a,b=b,a
print(a,b)

# %% [markdown]
# 3.Check if number is positive ,negative or zero

# %%
a=input()
print(a)
print("Even") if a%2==0 else print("zero") if a==0 else print("Odd")

# %% [markdown]
# 4.Convert celcius to ferenheit

# %%
celcius=input()
print(celcius)
ferenheit=(9*celcius+180)/5
print(ferenheit)

# %% [markdown]
# 5.Find area of circle

# %%
radius=input()
area_of_circle=3.14*radius*radius
print(area_of_circle)

# %% [markdown]
# 6.Find simple interest

# %%
salary=input()
if salary < 10000:
    print("Tax free")
elif salary < 20000:
     print("tax 5% on salary",0.05*salary)
elif salary>20001 and salary<50000:
    print("tax 10% on salary",0.1*salary)
elif salary>=50001:
    print("tax 20% on salary",0.2*salary)

# %% [markdown]
# 7. Force to take specific data types values as an input

# %%
while True:
    try:
        num = int(input("Enter an integer: "))
        break
    except ValueError:
        print("Invalid input! Please enter an integer only.")

print("You entered:", num)

# %% [markdown]
# 8.Find Largest of two numbers

# %%
a=input("enter number 1: ")
b=input("enter number 2: ")

if a>b:
     print("a is largest")
elif a==b:
    print("Both are equal")
else: print("b is largest")

# %% [markdown]
# 9.Find largest of three numbers

# %%
a,b,c=input("enter three numbers: ").split()
if a>b and a>c:
    print("a is largest")
elif b>a and b>c:
    print("b is largest")
else : print("c is largest")

# %%
10. find the second largest value among 10 values

# %%
largest=float('-inf')
secondLargest=float('-inf')

for i in range(10):
    num=input()
    num=int(num)
    if num > largest :
        secondLargest=largest
        largest=num
    elif num > secondLargest and num != largest:
        secondLargest = num

print("Largest value is:", largest)
print("Second largest value is:", secondLargest)
