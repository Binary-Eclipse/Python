# %% [markdown]
# 1.Explain difference between Python vs C/C++ syntax
#
# Answer:
#
# 1. Python easy to write as english but c/c++ more complex
# 2. python dont need to declared data type but c/c++ need to declared datatype
# 3. python dont need to use semicolon(;) but c/c++ need
#
# 4. python use indention or keep space before stateprint for if conditions
# like : if n %2==0:
#        (space)print("n is even")
#
# But other hand c/c++ use curl bracket for block of code
# like: if(n%2==0){
#     cout<<"n is even" or printf("n is even")
# }
#
# 5. input : python- input()  and c++- cin>>x and c-scanf()
# 6.compilation: python- interpreted but c/c++- compiled
# 7.memory handling : python- automatic and c/c++- manually probably
# 8. speed : python- slower and c/c++- faster
# 9. pointer support: python: no direct pointers & c/c++- full pointer support

# %% [markdown]
# 2. What are Python keywords?
#
# ANswer:
#
# if
# else
# for
# while
# def
# class
# return
# True
# False
# None

# %% [markdown]
# 3. Why indentation is important in Python?
#
# Answer:
#
# Indentation means spaces/tabs at the beginning of a line.
# Python uses indentation to define code blocks.
#
# correct:
#  if x > 0:
#     print("Positive")
#
# wrong:
# if x > 0:
# print("Positive")
#
# Without proper indentation, Python gives an error.

# %% [markdown]
# 4.Difference between is and ==
#
# ANswer:
#
# == check equality
# is checks memory / obeject identity

# %% [markdown]
# 5.What is dynamic typing?
#
# ANswer:
#
# Dynamic typing means Python automatically determines the datatype during runtime.
#
# You do not need to declare datatype manually.
#
# in python:
#
# x=10
# y="Hello"
#
# in c++:
#
# int x=10;
# string y="Hello";
