# %% [markdown]
# # Python Math
#  - is a built-in match function
#  - extensive math module

# %% [markdown]
# # Built-in function
# min()
# max()
# abs()
# pow()
#
# # built-in module
# import math
# math.sqrt()
# math.ceil()
# math.floor()
# math.pi

# %%
#built-in function
print(min(5,0,8))
print(max(5,0,8))
print(abs(-987))
print(pow(2,3))
# Out:
# 0
# 8
# 987
# 8

# %%
#built-in module
import math
print(math.sqrt(6))
print(math.ceil(1.89))
print(math.floor(1.89))
print(math.pi)
