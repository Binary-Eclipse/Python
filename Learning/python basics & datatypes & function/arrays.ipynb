# %% [markdown]
# # Array
#  - that contain different datatypes in it
#  - In python List use as Array
# Note: To work with array have to import a library, like the NumPy library
#
# python doesnot have built-in support for arrays, but python list can be use instead
