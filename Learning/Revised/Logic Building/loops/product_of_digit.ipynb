# %% [markdown]
# # 10. ✖️ Product of Digits
#
# Example:
#
# ```text
# 1234
# ```
#
# ```text
# 1 × 2 × 3 × 4 = 24
# ```
#
# ## Problems
#
# 1. Find product of digits.
# 2. Find product of non-zero digits.
# 3. Find product of even digits.
# 4. Find product of odd digits.
# 5. Find the largest product of digits.
# 6. Find the product of digits in a range.
#
# ---
