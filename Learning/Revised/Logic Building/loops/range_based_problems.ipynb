# %% [markdown]
# # 19. 🔁 Important Range-Based Problems
#
# 1. Prime numbers in a range.
# 2. Armstrong numbers in a range.
# 3. Perfect numbers in a range.
# 4. Palindrome numbers in a range.
# 5. Even numbers in a range.
# 6. Odd numbers in a range.
# 7. Numbers with exactly `n` divisors.
# 8. Numbers whose digit sum equals `n`.
# 9. Numbers whose digit product equals `n`.
# 10. Numbers divisible by multiple conditions.
#
# ---
