# %% [markdown]
# # 17. 🧮 Important Number-Theory Problems
#
# These are extremely valuable for loop practice.
#
# 1. Find all divisors of a number.
# 2. Count divisors.
# 3. Sum of divisors.
# 4. Proper divisors.
# 5. Greatest Common Divisor (GCD).
# 6. Least Common Multiple (LCM).
# 7. Check coprime numbers.
# 8. Find prime factors.
# 9. Find the largest factor.
# 10. Find the smallest factor.
# 11. Check abundant number.
# 12. Check deficient number.
# 13. Check automorphic number.
# 14. Check Harshad number.
# 15. Check neon number.
# 16. Check happy number.
# 17. Check strong number.
# 18. Check spy number.
# 19. Check duck number.
# 20. Check magic number.
#
# ---
