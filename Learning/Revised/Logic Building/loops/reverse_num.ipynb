# %% [markdown]
# # 8. 🔄 Reverse Numbers
#
# ## Basic
#
# 1. Reverse a number.
#
# ```text
# 12345 → 54321
# ```
#
# 2. Reverse a number using a loop.
# 3. Reverse a number using string slicing.
# 4. Reverse a number using a function.
#
# ## Intermediate
#
# 5. Handle trailing zeros.
#
# ```text
# 1200 → 21
# ```
#
# 6. Reverse negative numbers.
# 7. Reverse every number in a list.
# 8. Reverse only even numbers.
#
# ## Advanced
#
# 9. Reverse a number without strings.
# 10. Check palindrome using reversal.
# 11. Reverse only selected digits.
#
# ---
