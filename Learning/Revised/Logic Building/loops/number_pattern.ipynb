# %% [markdown]
# # 12. 🔢 Number Patterns
#
# ## Pattern 1
#
# ```text
# 1
# 12
# 123
# 1234
# 12345
# ```
#
# ## Pattern 2
#
# ```text
# 1
# 22
# 333
# 4444
# 55555
# ```
#
# ## Pattern 3
#
# ```text
# 12345
# 1234
# 123
# 12
# 1
# ```
#
# ## Pattern 4
#
# ```text
# 54321
# 5432
# 543
# 54
# 5
# ```
#
# ## Practice Questions
#
# 1. Increasing numbers.
# 2. Decreasing numbers.
# 3. Repeated numbers.
# 4. Reverse numbers.
# 5. Odd number patterns.
# 6. Even number patterns.
# 7. Continuous number patterns.
# 8. Alternating number patterns.
# 9. Number pyramid.
# 10. Number diamond.
#
# ---
