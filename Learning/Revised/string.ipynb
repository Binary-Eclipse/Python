# %% [markdown]
# # String

# %% [markdown]
# ## Reverse String

# %%
text= "Hello"

# slicing method
reversed_text=text[::-1]
print(reversed_text)

# reversed()
reversed_text2="".join(reversed(text))
print(reversed_text2)
# Out:
# olleH
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       4 reversed_text=text[::-1]
#       5 print(reversed_text)
#       6
#       7 # reversed()
# ----> 8 reversed2="".join(reversed(text))
#       9 print(reversed2)
#
# TypeError: 'str' object is not callable
